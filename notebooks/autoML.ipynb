# %%
import pycaret
import pandas as pd

fly = pd.read_csv("D:\PENS-EEPIS\SDT A Semester 4 2026\Sistem Rekomendasi\Projek Mini\Airline Quality Ratings.csv")

# %%
from pycaret.classification import *
setup = setup(data=fly, target="Satisfaction", session_id=123)
# Out:
# <style type="text/css">
# #T_ce143_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce143">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce143_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ce143_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce143_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce143_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ce143_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ce143_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce143_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ce143_row1_col1" class="data row1 col1" >Satisfaction</td>
#     </tr>
#     <tr>
#       <th id="T_ce143_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_204b7 th {
#   text-align: left;
# }
# ...
